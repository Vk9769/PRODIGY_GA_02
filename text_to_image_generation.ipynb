# %% [markdown]
# <a href="https://colab.research.google.com/github/Vk9769/PRODIGY_GA_02/blob/main/text_to_image_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Install the min-dalle library

# %%
# !pip install min-dalle -q

# %%
from min_dalle import MinDalle
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the model

# %%
model = MinDalle(is_mega=True, is_reusable=True)
# Out:
# using device cuda
# intializing TextTokenizer
# initializing DalleBartEncoder
# initializing DalleBartDecoder
# initializing VQGanDetokenizer

# %% [markdown]
# # Define the text prompt

# %%
text = "1967 Mustang in black and gold colour"
seed = 6
grid_size = 1

# %% [markdown]
# # Generate the image

# %%
image = model.generate_image(text, seed, grid_size)

# %% [markdown]
# # Display the image using PIL

# %%
image.show()

# %% [markdown]
# # Alternatively, display the image using matplotlib

# %%
plt.imshow(image)
plt.axis('off')
plt.show()
